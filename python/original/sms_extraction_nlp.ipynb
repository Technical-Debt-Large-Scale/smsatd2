# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import util.utilities as util
import pandas as pd

# %% [markdown]
# # 2 Special analyses

# %%
def macro_wordcloud_content_analysis(path_file, name):
    util.generateWordcloudFromTextFile(path_file, name)
    util.contentAnalysisFromTextFile(path_file)

# %%
# Import papers spreadsheet to dataset
df_sms_extraction = pd.read_excel('../../dataset/Extraction_form.xlsx')

# %% [markdown]
# ## 2.1 We are creating a text file appended for each analyzed column.

# %%
path_abstracts_file = '../../dataset/abstracts.txt'
path_goals_file = '../../dataset/goals.txt'
path_conclusions_file = '../../dataset/conclusions.txt'
path_futures_file = '../../dataset/futures.txt'

path_strong_aspects = '../../dataset/strongest.txt'
path_weak_aspects = '../../dataset/weaks.txt'
path_scientific_rigor = '../../dataset/rigors.txt'
path_paper_relevance = '../../dataset/relevances.txt'
path_limitations = '../../dataset/limitations.txt'

column_names_df_sms_extraction = df_sms_extraction.columns
abstract_column = 'Abstract'
goal_column = 'Main aim (Goal)'
conclusions_column = 'Extra (Conclusion)'
strong_aspects_column = 'Strong Aspects'
weak_aspects_column = 'Weak Aspects'
scientific_rigor_column = 'Scientific Rigor'
paper_relevance_column = 'Paper relevance'
limitations_column = 'Limitations'
future_column = 'Future Works'

util.appendContentsInTextFile(path_abstracts_file, df_sms_extraction[abstract_column])
util.appendContentsInTextFile(path_goals_file, df_sms_extraction[goal_column])
util.appendContentsInTextFile(path_conclusions_file, df_sms_extraction[conclusions_column])
util.appendContentsInTextFile(path_strong_aspects, df_sms_extraction[strong_aspects_column])
util.appendContentsInTextFile(path_weak_aspects, df_sms_extraction[weak_aspects_column])
util.appendContentsInTextFile(path_scientific_rigor, df_sms_extraction[scientific_rigor_column]) 
util.appendContentsInTextFile(path_paper_relevance, df_sms_extraction[paper_relevance_column]) 
util.appendContentsInTextFile(path_limitations, df_sms_extraction[limitations_column])
util.appendContentsInTextFile(path_futures_file, df_sms_extraction[future_column])
# Out:
# The file ../../dataset/abstracts.txt was created with sucess!
# The ../../dataset/abstracts.txt has appended all abstract content with sucess!
# The file ../../dataset/goals.txt was created with sucess!
# The ../../dataset/goals.txt has appended all abstract content with sucess!
# The file ../../dataset/conclusions.txt was created with sucess!
# The ../../dataset/conclusions.txt has appended all abstract content with sucess!
# The file ../../dataset/strongest.txt was created with sucess!
# The ../../dataset/strongest.txt has appended all abstract content with sucess!
# The file ../../dataset/weaks.txt was created with sucess!
# The ../../dataset/weaks.txt has appended all abstract content with sucess!
# The file ../../dataset/rigors.txt was created with sucess!
# The ../../dataset/rigors.txt has appended all abstract content with sucess!
# The file ../../dataset/relevances.txt was created with sucess!
# The ../../dataset/relevances.txt has appended all abstract content with sucess!
# The file ../../dataset/limitations.txt was created with sucess!
# The ../../dataset/limitations.txt has appended all abstract content with sucess!
# The file ../../dataset/futures.txt was created with sucess!
# The ../../dataset/futures.txt has appended all abstract content with sucess!

# %%
# Allows NLP (Natural Language Process) for each content in dataframe
util.loadSupportTokenization()
# Out:
# Starting download punkt to suport tokeninzing...
# Download concluído.
# Unzip concluído.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/armandosoaressousa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## 2.2 Generate the wordcloud of abstracts content and content analysis

# %%
macro_wordcloud_content_analysis(path_abstracts_file, 'abstracts')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 455)
# ('and', 291)
# ('debt', 140)
# ('that', 116)
# ('architectural', 102)
# ('technical', 94)
# ('software', 93)
# ('this', 74)
# ('for', 69)
# ('architecture', 65)
# ('are', 57)
# ('system', 49)
# ('can', 47)
# ('with', 42)
# ('study', 41)
# ('design', 38)
# ('has', 34)
# ('development', 33)
# ('from', 33)
# ('these', 29)
# ('systems', 29)
# ('maintenance', 28)
# ('have', 28)
# ('their', 27)
# ('project', 26)
# ('code', 26)
# ('which', 26)
# ('results', 26)
# ('been', 24)
# ('not', 24)
# ('quality', 24)
# ('paper', 24)
# ('how', 24)
# ('time', 23)
# ('case', 23)
# ('atd', 21)
# ('refactoring', 21)
# ('large', 20)
# ('interest', 20)
# ('its', 19)
# ('such', 19)
# ('different', 19)
# ('smells', 19)
# ('source', 19)
# ('analysis', 19)
# ('architects', 18)
# ('over', 18)
# ('decisions', 17)
# ('files', 17)
# ('evolution', 17)
# ('approach', 16)
# ('identified', 16)
# ('issues', 16)
# ('metrics', 16)
# ('they', 16)
# ('tools', 16)
# ('companies', 16)
# ('but', 15)
# ('impact', 15)
# ('was', 15)
# ('conducted', 15)
# ('costs', 15)
# ('flaws', 15)
# ('most', 15)
# ('however', 14)
# ('model', 14)
# ('other', 14)
# ('research', 14)
# ('identify', 14)
# ('into', 14)
# ('more', 14)
# ('using', 14)
# ('both', 14)
# ('practitioners', 14)
# ('components', 13)
# ('show', 13)
# ('based', 13)
# ('our', 13)
# ('requirements', 13)
# ('used', 12)
# ('business', 12)
# ('modularity', 12)
# ('method', 12)
# ('maintainability', 12)
# ('important', 12)
# Número total de palavras é 8072
# Número de palavras únicas é 1646

# %% [markdown]
# ## 2.3 Generate the wordcloud of goals content and content analysis

# %%
macro_wordcloud_content_analysis(path_goals_file, 'goals')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 524)
# ('and', 249)
# ('for', 76)
# ('that', 74)
# ('software', 73)
# ('this', 71)
# ('atd', 68)
# ('debt', 67)
# ('architectural', 66)
# ('are', 60)
# ('architecture', 60)
# ('how', 55)
# ('with', 54)
# ('can', 46)
# ('study', 43)
# ('what', 43)
# ('technical', 36)
# ('have', 35)
# ('system', 34)
# ('their', 33)
# ('design', 33)
# ('our', 31)
# ('from', 31)
# ('project', 30)
# ('paper', 30)
# ('interest', 28)
# ('these', 28)
# ('which', 28)
# ('files', 27)
# ('refactoring', 26)
# ('such', 25)
# ('development', 24)
# ('approach', 23)
# ('research', 23)
# ('code', 23)
# ('tools', 23)
# ('maintenance', 22)
# ('smells', 22)
# ('quality', 22)
# ('identify', 21)
# ('questions', 21)
# ('debts', 21)
# ('architects', 20)
# ('time', 20)
# ('not', 20)
# ('different', 20)
# ('case', 19)
# ('index', 19)
# ('based', 19)
# ('each', 19)
# ('impact', 18)
# ('using', 18)
# ('evolution', 18)
# ('source', 17)
# ('large', 17)
# ('analysis', 17)
# ('systems', 17)
# ('they', 16)
# ('more', 15)
# ('following', 15)
# ('issues', 15)
# ('identified', 15)
# ('between', 15)
# ('accumulation', 15)
# ('were', 15)
# ('other', 14)
# ('smell', 14)
# ('two', 14)
# ('over', 14)
# ('model', 13)
# ('its', 13)
# ('main', 13)
# ('goal', 13)
# ('metrics', 13)
# ('groups', 13)
# ('process', 13)
# ('decisions', 12)
# ('focus', 12)
# ('also', 12)
# ('file', 12)
# ('related', 12)
# ('used', 12)
# Número total de palavras é 7869
# Número de palavras únicas é 1500

# %% [markdown]
# ## 2.4 Generate the wordcloud of conclusions content and content analysis

# %%
macro_wordcloud_content_analysis(path_conclusions_file, 'conclusions')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the',
# ('between', 5)
# ('effort', 5)
# ('these', 5)
# ('architecture', 5)
# ('based', 5)
# ('their', 5)
# ('investigation', 5)
# ('track', 5)
# ('next', 5)
# ('step', 5)
# ('microservices', 5)
# ('include', 4)
# ('authors', 4)
# ('extend', 4)
# ('support', 4)
# ('most', 4)
# ('project', 4)
# ('results', 4)
# ('first', 4)
# ('measures', 4)
# ('management', 4)
# Número total de palavras é 2364
# Número de palavras únicas é 749

# %% [markdown]
# ## 2.6 Generate extra wordcloud and content analysis

# %%
macro_wordcloud_content_analysis(path_strong_aspects, 'strong')

macro_wordcloud_content_analysis(path_weak_aspects, 'weak')

macro_wordcloud_content_analysis(path_scientific_rigor, 'rigor')

macro_wordcloud_content_analysis(path_paper_relevance, 'relevance')

macro_wordcloud_content_analysis(path_limitations, 'limitations')
# Out:
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 79)
# ('and', 47)
# ('study', 29)
# ('authors', 25)
# ('software', 20)
# ('that', 20)
# ('atd', 18)
# ('proposed', 15)
# ('real', 15)
# ('using', 12)
# ('case', 12)
# ('architectural', 11)
# ('from', 11)
# ('about', 10)
# ('code', 9)
# ('with', 9)
# ('architecture', 9)
# ('identify', 8)
# ('data', 8)
# ('metrics', 8)
# ('calculate', 8)
# ('large', 8)
# ('approuch', 7)
# ('source', 7)
# ('check', 7)
# ('important', 7)
# ('effort', 7)
# ('debt', 6)
# ('conducted', 6)
# ('showed', 6)
# ('was', 6)
# ('atdi', 5)
# ('company', 5)
# ('index', 4)
# ('paper', 4)
# ('model', 4)
# ('method', 4)
# ('measure', 4)
# ('this', 4)
# ('technical', 4)
# ('via', 4)
# ('development', 4)
# ('are', 4)
# ('complex', 4)
# ('access', 3)
# ('open', 3)
# ('projects', 3)
# ('shows', 3)
# ('refactoring', 3)
# ('has', 3)
# ('quality', 3)
# ('for', 3)
# ('evolution', 3)
# ('most', 3)
# ('besides', 3)
# ('there', 3)
# ('can', 3)
# ('used', 3)
# ('interest', 3)
# ('cost', 3)
# ('fix', 3)
# ('tools', 3)
# ('change', 3)
# ('scenarios', 3)
# ('estimate', 3)
# ('companies', 3)
# ('smells', 3)
# ('available', 3)
# ('collected', 3)
# ('systems', 3)
# ('repository', 3)
# ('tracking', 3)
# ('documents', 2)
# ('without', 2)
# ('set', 2)
# ('validate', 2)
# ('other', 2)
# ('five', 2)
# ('types', 2)
# ('benefits', 2)
# ('how', 2)
# ('during', 2)
# ('hotspot', 2)
# ('part', 2)
# ('should', 2)
# ('more', 2)
# ('modularity', 2)
# ('principal', 2)
# Número total de palavras é 1234
# Número de palavras únicas é 428
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the', 46)
# ('not', 17)
# ('and', 15)
# ('about', 9)
# ('only', 9)
# ('study', 9)
# ('was', 8)
# ('calculate', 8)
# ('there', 7)
# ('that', 7)
# ('architectural', 7)
# ('dataset', 6)
# ('reproduce', 6)
# ('used', 6)
# ('using', 5)
# ('authors', 5)
# ('cost', 4)
# ('data', 4)
# ('available', 4)
# ('source', 4)
# ('are', 4)
# ('other', 4)
# ('this', 4)
# ('possible', 4)
# ('identify', 4)
# ('atdi', 4)
# ('for', 4)
# ('each', 4)
# ('company', 4)
# ('atd', 4)
# ('did', 4)
# ('formula', 3)
# ('should', 3)
# ('projects', 3)
# ('from', 3)
# ('have', 3)
# ('languages', 3)
# ('can', 3)
# ('proposed', 3)
# ('manual', 3)
# ('principal', 3)
# ('software', 3)
# ('effort', 3)
# ('fix', 3)
# ('identification', 3)
# ('technical', 3)
# ('evaluate', 3)
# ('repliaction', 3)
# ('debt', 3)
# ('index', 3)
# ('calculation', 2)
# ('performed', 2)
# ('real', 2)
# ('shared', 2)
# ('studied', 2)
# ('open', 2)
# ('all', 2)
# ('which', 2)
# ('were', 2)
# ('implemented', 2)
# ('java', 2)
# ('apache', 2)
# ('would', 2)
# ('different', 2)
# ('with', 2)
# ('our', 2)
# ('results', 2)
# ('oss', 2)
# ('but', 2)
# ('project', 2)
# ('generalize', 2)
# ('private', 2)
# ('called', 2)
# ('interest', 2)
# ('release', 2)
# ('necessary', 2)
# ('paper', 2)
# ('scientific', 2)
# ('architect', 2)
# ('kit', 2)
# ('studythe', 2)
# ('method', 2)
# ('case', 2)
# ('one', 2)
# ('tool', 2)
# ('shoud', 2)
# Número total de palavras é 681
# Número de palavras únicas é 246
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('yes', 173)
# ('characterization', 39)
# ('bibliographic', 39)
# ('review', 39)
# ('data', 39)
# ('collection', 39)
# ('hypothesis', 39)
# ('experimentation', 39)
# ('results', 39)
# ('final', 39)
# ('goodproblem', 13)
# ('the', 8)
# ('regularproblem', 8)
# ('good', 6)
# ('greatproblem', 6)
# ('and', 5)
# ('authors', 5)
# ('extra', 4)
# ('debt', 4)
# ('architectural', 4)
# ('technical', 3)
# ('index', 3)
# ('analysis', 3)
# ('show', 3)
# ('this', 2)
# ('paper', 2)
# ('research', 2)
# ('proposed', 2)
# ('cited', 2)
# ('references', 2)
# ('important', 2)
# ('related', 2)
# ('works', 2)
# ('about', 2)
# ('defined', 2)
# ('set', 2)
# ('using', 2)
# ('statistical', 2)
# ('with', 2)
# ('weakproblem', 2)
# ('weak', 2)
# ('problem', 1)
# ('used', 1)
# ('quantitative', 1)
# ('qualitative', 1)
# ('evaluate', 1)
# ('tools', 1)
# ('particular', 1)
# ('highlight', 1)
# ('sonarqube', 1)
# ('was', 1)
# ('groups', 1)
# ('smell', 1)
# ('detection', 1)
# ('arcan', 1)
# ('tool', 1)
# ('formulas', 1)
# ('represent', 1)
# ('shown', 1)
# ('comparing', 1)
# ('qualitas', 1)
# ('corpos', 1)
# ('have', 1)
# ('detailed', 1)
# ('effort', 1)
# ('process', 1)
# ('type', 1)
# ('architecture', 1)
# ('issue', 1)
# ('identification', 1)
# ('evaluation', 1)
# ('roots', 1)
# ('som', 1)
# ('simple', 1)
# ('poornanproblem', 1)
# ('goodnannanproblem', 1)
# ('actually', 1)
# ('only', 1)
# ('two', 1)
# ('pages', 1)
# ('there', 1)
# ('scientific', 1)
# ('goodnanproblem', 1)
# ('weaknannanproblem', 1)
# ('regularnanproblem', 1)
# ('weaknan', 1)
# Número total de palavras é 760
# Número de palavras únicas é 94
# Gera lista de tokens.
# Faz a tokenizacao do conteudo artigos.
# Gera lista de palavras
# Normaliza todas as palavras para minusculas.
# Gera o conjunto de palavras unicas - vocabulario.
# Calcula a frequencia da lista de palavras
# Frequencia de palavras (mais de 3 caracteres)
# ('the',