# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

import pandas as pd
import util.utilities as util

# %%
df_sms_extraction = util.load_dataset(my_path='../../dataset/Extraction_form_basic.xlsx')
df_sms_extraction = util.add_column_sp(df_sms_extraction)

df_my_data_papers = util.selected_papers(df_sms_extraction)
df_my_data_papers['Title'] = df_my_data_papers['Title'].apply(lambda x: util.remove_enter(x))

util.create_latex_table(my_df=df_my_data_papers, my_path='../../latex', my_file_name='mytable_papers.tex')

util.create_markdown_table(my_df=df_my_data_papers, my_path='../../md', my_file_name='mytable_papers.md')

df_my_data_papers
# Out:
# Arquivo ../../latex/mytable_papers.tex  gerado com sucesso!
# Arquivo ../../md/mytable_papers.md  gerado com sucesso!
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       sp  \
# 0    SP1
# 1    SP2
# 2    SP3
# 3    SP4
# 4    SP5
# 5    SP6
# 6    SP7
# 7    SP8
# 8    SP9
# 9   SP10
# 10  SP11
# 11  SP12
# 12  SP13
# 13  SP14
# 14  SP15
# 15  SP16
# 16  SP17
# 17  SP18
# 18  SP19
# 19  SP20
# 20  SP21
# 21  SP22
# 22  SP23
# 23  SP24
# 24  SP25
# 25  SP26
# 26  SP27
# 27  SP28
# 28  SP29
# 29  SP30
# 30  SP31
# 31  SP32
# 32  SP33
# 33  SP34
# 34  SP35
# 35  SP36
# 36  SP37
# 37  SP38
# 38  SP39
# 39  SP40
# 40  SP41
# 41  SP42
# 42  SP43
# ...

# %%
c_citation = 'Citation'
c_title = 'Title'
cq1 = 'Q1 Type of ATD (Based on Li et al 2015)'
cq2 = 'Q2(Measure)'
cq3 = 'Q3(Monitoring)'
cq4 = 'Q4(Techniques and tools)'                                                                  
cq5 = 'Q5(calculate the cost)'                                                                
cq6 = 'Q6(How ATD is management?)'
cq7 = 'Q7 Research Type (Evaluation Research, Validation Research, Solution Proposal, Philosophycal paper, Other)'

#questions_columns = ['Paper Id','sp', c_citation, c_title, cq1, cq2, cq3, cq4, cq5, cq7]
questions_columns = ['Paper Id','sp', c_citation, c_title]
list_id_main_papers = [1,2,4,5,9,10,21,22,27,31,30,33, 35,48,81]
print('Amount of important papers: {}'.format(len(list_id_main_papers)))
df_sms_extraction[questions_columns][df_sms_extraction['Paper Id'].isin(list_id_main_papers)]
# Out:
# Amount of important papers: 15
#     Paper Id    sp              Citation  \
# 0          1   SP1     Perez et al. 2019
# 1          2   SP2    Martini et al 2017
# 3          4   SP4    Snipes et al. 2018
# 4          5   SP5    Nayebi et al. 2019
# 6          9   SP7        Li et al. 2014
# 7         10   SP8   Martini et al. 2016
# 13        21  SP14        Li et al. 2015
# 14        22  SP15   Martini et al. 2014
# 15        27  SP16   Martini et al. 2016
# 16        30  SP17   Martini et al. 2018
# 18        48  SP19    Kazman et al. 2015
# 21        33  SP22      Nord et al. 2012
# 24        31  SP25  Eliasson et al. 2015
# 35        35  SP36    Martini et al 2015
# 39        81  SP40     Curtis et al 2012
#
#                                                                                                                                                                         Title
# ...
